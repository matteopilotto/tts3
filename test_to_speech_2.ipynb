# %%
import torch
# import torch.nn.functional as F

device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %%
from IPython.display import Markdown, HTML
from whisperspeech.pipeline import Pipeline

pipe = Pipeline(s2a_ref='collabora/whisperspeech:s2a-q4-tiny-en+pl.model', device=device)

# %%
pipe.generate_to_notebook("""
This is the first demo of Whisper Speech, a fully open source text-to-speech model trained by Collabora and Lion on the Juwels supercomputer.
""".strip())
# Out:
#  |████████████████████████████████████████| 100.00% [704/704 00:04<00:00]
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
pipe.generate_to_notebook("""
This is the first demo of Whisper Speech, a fully open source text-to-speech model trained by Collabora and Lion on the Juwels supercomputer.
""".strip(), lang='en', speaker='./coach_bennet_audio_30sec.wav')
# Out:
#  |████████████████████████████████████████| 100.00% [686/686 00:04<00:00]
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# pipe = Pipeline(s2a_ref='collabora/whisperspeech:s2a-q4-base-en+pl.model')
pipe = Pipeline(device=device)

speech = """
It's Coach Bennett here!
Listen up, champions!
Here's your nugget of wisdom for today: Your mind quits a thousand times before your body does.
So when that little voice says 'I'm done,' you look it straight in the eye and say 'We're just getting started!'
Remember, every step is a victory, every mile a triumph.
Your legs might be screaming, but your heart? It's singing!
So lace up tight, stand tall, and show that road who's boss.
You're not just running, you're rewriting your story with every stride.
""".strip()
# Now get out there and make the pavement proud.

pipe.generate_to_notebook(speech, lang='en', speaker='./coach_bennet_audio_30sec.wav')
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/utils/weight_norm.py:30: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
#  |████████████████████████████████████████| 100.00% [2246/2246 01:04<00:00]
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
pipe.generate_to_file("./sample.wav", speech, lang='en', speaker='./coach_bennet_audio_30sec.wav')
